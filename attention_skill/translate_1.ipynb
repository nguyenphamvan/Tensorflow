# %% [markdown]
# # Import thư viện, tiền xử lí dữ liệu

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import random
import os
import io
import string
import re
from sklearn.model_selection import train_test_split

print(tf.__version__)

# dùng eager mode trong tensor    
tf.enable_eager_execution()

def preprocess(sentence):
    sent = sentence.lower()
    sent = sent.strip()
    sent = re.sub("'"," ",sent)
    sent = re.sub("\s+"," ",sent)
    sent = ''.join([char for char in sent if char not in exclude])
    sent = "<start> " + sent + " <end>"
    return sent

# load data
en_filename = "./dataset/train.en.txt"
vi_filename = "./dataset/train.vi.txt"

raw_en_lines = open(en_filename, encoding='utf-8').read().strip().split("\n")
raw_vi_lines = open(vi_filename, encoding='utf-8').read().strip().split("\n")
exclude = list(string.punctuation) + list(string.digits)

en_lines = []
vi_lines = []
min_len, max_len = 10, 14

# với mục đích demo, mình sẽ không xử lí những câu quá dài,
# loại bỏ những câu có độ dài không nằm trong khoảng (min_len, max_len)
for eline, vline in zip(raw_en_lines, raw_vi_lines):
    eline = preprocess(eline)
    vline = preprocess(vline)
    if min_len < len(eline.split(" ")) < max_len and min_len < len(vline.split(" ")) < max_len:
        en_lines.append(eline)
        vi_lines.append(vline)
# Out:
# 1.15.0-dev20190803

# %%
print(en_lines)
# Out:
# ['<start> rachel pike  the science behind a climate headline <end>', '<start> they wrote almost a thousand pages on the topic  <end>', '<start> christopher decharms  a look inside the brain in real time <end>', '<start> i aposm going to tell you about that technology  <end>', '<start> but i want to leave with you the big question  <end>', '<start> and they themselves had not known they cared  <end>', '<start> i was past  when my father died  <end>', '<start> but within the reels lie purpose and meaning  <end>', '<start> let me take you on a little tour  <end>', '<start> i aposm not going to minimize those concerns  <end>', '<start> geert chatrou  a whistleblower you haven apost heard <end>', '<start> so  okay  i aposm going to america  <end>', '<start> well actually  you are going to whistle along  <end>', '<start> geert chatrou  thank you  thank you  <end>', '<start> so he aposs mario  he aposs our son  <end>', '<start> but in the end everything seemed to be under control  <end>', '<start> so he got the right weight at birth  <end>', '<start> and that has been really a tough time  <end>', '<start> did you guess the one that was dry  <end>', '<start> so what aposs going on here  what aposs happening  <end>', '<start> without water  the bacteria won apost survive  <end>', '<start> i kept on doing this for a while  <end>', '<start> how much do i stand to gain from cheating  <end>', '<start> will they cheat more  or will they cheat less  <end>', '<start> we aposve learned that a lot of people can cheat  <end>', '<start> okay  one  two  three  go  <end>', '<start> well done  thank you  thank you very much  <end>', '<start> i aposm reaching around and i aposm reaching up  <end>', '<start> it just didn apost work out for you  <end>', '<start> how many of you won just won thumb  <end>', '<start> all right  i have very good news for you  <end>', '<start> this is tootsie aposs orchid lounge in nashville  <end>', '<start> the clientele behavior was very much the same too  <end>', '<start> is that a kind of model for creativity  <end>', '<start> and the size of the room is not that big  <end>', '<start> it aposs larger than some of the other symphony halls  <end>', '<start> popular music  coming along at the same time  <end>', '<start> and a new form of music was born  <end>', '<start> and he aposs singing right into your ear  <end>', '<start> and they no longer have to be exactly the same  <end>', '<start> and another new form of music was born  <end>', '<start> the tempos are medium  it sounds big  <end>', '<start> one of the new ones is the automobile  <end>', '<start> presumably  this is just for christian music  <end>', '<start> that aposs what keeps you from getting help  <end>', '<start> and i don apost know what the solution is  <end>', '<start> this is a dream come true  thank you  <end>', '<start> ronny edry  israel and iran  a love story  <end>', '<start> who is everybody  quot quot everybody  quot <end>', '<start> they said  quot syria  quot quot syria  quot <end>', '<start> and we were just at the beginning of the story  <end>', '<start> you have lebanon that just  a few days ago  <end>', '<start> look at this one  this is the iranlovesisrael page  <end>', '<start> i know how it can look really bad  <end>', '<start> i offered five cents each for bottle caps  <end>', '<start> here are the  bottle caps they collected  <end>', '<start> that day i ended up spending nearly   <end>', '<start> this is the legacy we are leaving to future generations  <end>', '<start> and that aposs going to pose an enormous problem  <end>', '<start> we aposre very hungry for fossil fuels too  <end>', '<start> and the food obviously went off very quickly  <end>', '<start> and they aposre coming into the city by rail  <end>', '<start> so what are we going to do about that  <end>', '<start> because i think it aposs an urgent question  <end>', '<start> that aposs the trailer  pretty much finished  <end>', '<start> imagine  if you will  these two ideas t ...

# %%
print(vi_lines)
# Out:
# ['<start> khoa học đằng sau một tiêu đề về khí hậu <end>', '<start> họ viết gần  trang về chủ đề này  <end>', '<start> christopher decharms quét não bộ theo thời gian thực <end>', '<start> tôi sẽ cho bạn biết về công nghệ đó  <end>', '<start> nhưng tôi có một câu hỏi lớn dành cho bạn  <end>', '<start> và chúng không tự biết rằng chúng quan tâm  <end>', '<start> tôi đã hơn  khi bố tôi mất  <end>', '<start> nhưng trong những cuộn phim là mục đích và ý nghĩa <end>', '<start> hãy để tôi đưa các bạn thăm quan một chút  <end>', '<start> tôi sẽ không coi thường những quan ngại này  <end>', '<start> một người huýt gió bạn chưa từng biết đến <end>', '<start> đựoc thôi  tôi chuẩn bị được đi mỹ  <end>', '<start> thật ra  bạn sẽ huýt gió cùng tôi <end>', '<start> geert chatrou  cám ơn  cám ơn  <end>', '<start> đây là mario  con trai chúng tôi  <end>', '<start> nhưng cuối cùng thì mọi việc dường như đã ổn  <end>', '<start> nên bé sinh ra được đủ cân nặng  <end>', '<start> đó thực sự là quãng thời gian khó khăn  <end>', '<start> bạn đoán ra chiếc nào khô rồi chứ  <end>', '<start> vậy thì chuyện gì đã xảy ra vậy  <end>', '<start> không có nước  vi khuẩn không kí sinh được  <end>', '<start> tôi tiếp tục làm thí nghiệm này  thời gian <end>', '<start> tôi sẽ kiếm được bao nhiêu nếu gian lận  <end>', '<start> họ sẽ gian lận ít hơn  hay nhiều hơn  <end>', '<start> chúng tôi rút ra rằng nhiều người có thể gian lận <end>', '<start> ok  một  hai  ba  đi  <end>', '<start> tốt  cảm ơn bạn  cảm ơn rất nhiều  <end>', '<start> tôi vươn ra xung quanh và tôi vươn lên trước  <end>', '<start> nó chỉ là không làm việc cho bạn  <end>', '<start> bao nhiêu người trong số bạn đã giành chiến thắng  <end>', '<start> được rồi  tôi có một tin tốt cho bạn  <end>', '<start> đây là orchid lounge ở tootsie ở nashville  <end>', '<start> hành xử của người nghe cũng khá giống  <end>', '<start> có phải đó là một mô hình sáng tạo  <end>', '<start> kích cỡ của căn phòng không to tới mức này  <end>', '<start> nó lớn hơn một vài hội trường nhạc giao hưởng  <end>', '<start> nhạc pop  xuất hiện cùng vào thời kỳ này  <end>', '<start> và một loại hình âm nhạc mới ra đời  <end>', '<start> và anh ta hát ngay vào tai bạn  <end>', '<start> và chúng không còn hoàn toàn giống nhau nữa  <end>', '<start> và một loại hình nhạc mới ra đời  <end>', '<start> tốc độ vừa phải  âm lượng lớn  <end>', '<start> một trong những địa điểm đó là trong xe hơi  <end>', '<start> có lẽ  nó chỉ dành cho nhạc công giáo  <end>', '<start> đó là những thứ ngăn bạn nhận sự giúp đỡ  <end>', '<start> và tôi chưa biết lời giải là gì  <end>', '<start> đây là giấc mơ có thật  cảm ơn  <end>', '<start> israel và iran  một câu chuyện tình  <end>', '<start> ai là mọi người  quot quot tất cả  quot <end>', '<start> họ nói quot syria  quot quot syria  quot <end>', '<start> và đó mới chỉ là sự bắt đầu  <end>', '<start> cũng có lebanon nữa  mới vài ngày trước  <end>', '<start> hãy nhìn cái này xem  đây là trang iranyêuisrael  <end>', '<start> tôi biết vì sao mọi việc trông rất tồi tệ  <end>', '<start> tôi đề nghị trả năm xu cho mỗi nắp chai  <end>', '<start> đây là   nắp chai họ thu thập được  <end>', '<start> ngày hôm đó tôi phải tiêu gần   <end>', '<start> đây là di sản ta để lại cho hậu thế  <end>', '<start> điều đó đang đặt ra một vấn đề to lớn  <end>', '<start> chúng ta cũng rất cần các nhiên liệu dự trữ  <end>', '<start> và tất nhiên  thực phẩm hết rất nhanh  <end>', '<start> và chúng được chở vào thành phố bằng tàu hoả  <end>', '<start> vậy chúng ta sẽ làm gì với điều đó  <end>', '<start> bởi theo tôi đó là một câu hỏi cấp thiết  <end>', '<start> đó là toa xe khi gần hoàn thiện  <end>', '<start> hãy tưởng tượng  hai ý tưởng cùng lúc <end>', '<start> làm sao hệ thần kinh có thể sai đến thế  <end>', '<start> và vì những cảnh tượng như thế này  <end>', '<start> không có thuốc chữa  va không có vắc xin  <end>', '<start> không còn nhiều nơi tồn tại căn bệnh này  <end>', '<start> hàng trăm người chết trẻ con cũng như người lớn ...

# %% [markdown]
# # Xử lí ngôn ngữ với class Language

# %%
class Language():
    def __init__(self, lines):
        self.lines = lines
        self.word2id = {}
        self.id2word = {}
        self.vocab = set()
        self.max_len = 0
        self.min_len = 0
        self.vocab_size = 0
        self.init_language_params()
        
    def init_language_params(self):
        for line in self.lines:
            self.vocab.update(line.split(" "))
        self.word2id['<pad>'] = 0
        for id, word in enumerate(self.vocab):
            self.word2id[word] = id + 1
        for word, id in self.word2id.items():
            self.id2word[id] = word
        self.max_len = max([len(line.split(" ")) for line in self.lines])
        self.min_len = min([len(line.split(" ")) for line in self.lines])
        self.vocab_size = len(self.vocab) + 1
    
    def sentence_to_vector(self, sent):
        return np.array([self.word2id[word] for word in sent.split(" ")])
    
    def vector_to_sentence(self, vector):
        return " ".join([self.id2word[id] for id in vector])

# %% [markdown]
# # Tạo dữ liệu cho train, validate:

# %%
class Encode(tf.keras.Model):
    def __init__(self, embedding_size, vocab_size, hidden_units):
        super(Encode, self).__init__()
        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_size)
        self.GRU = tf.keras.layers.GRU(
            hidden_units,
            return_sequences=True,
            return_state=True,
            recurrent_initializer='glorot_uniform'
        )
        self.hidden_units = hidden_units
    
    def call(self, x, hidden_state):
        x = self.Embedding(x)
        outputs, last_state = self.GRU(x, hidden_state)
        return outputs, last_state
    
    def init_hidden_state(self, batch_size):
        return tf.zeros([batch_size, self.hidden_units])

# %% [markdown]
# # Attention

# %%
class Attention(tf.keras.Model):
    def __init__(self, hidden_units):
        super(Attention, self).__init__()
        self.W_out_encode = tf.keras.layers.Dense(hidden_unit)
        self.W_state = tf.keras.layers.Dense(hidden_unit)
        self.V = tf.keras.layers.Dense(1)
        
    def call(self, encode_outs, pre_state):
        pre_state = tf.expand_dims(pre_state, axis=1)
        pre_state = self.W_state(pre_state)
        encode_outs = self.W_out_encode(encode_outs)
        score = self.V(
            tf.nn.tanh(
                pre_state + encode_outs_outs
            )
        )
        
        score = tf.nn.softmax(score, axis=1)
        context_vector = score*encode_outs_outs
        context_vector = tf.reduce_sum(context_vector, axis=1)
        return context_vector, score

# %% [markdown]
# # Decode

# %%
class Decode(tf.keras.Model):
    def __init__(self, vocab_size, embedding_size, hidden_units):
        super(Decode, self).__init__()
        self.hidden_units = hidden_units
        self.Embedding = tf.keras.layers.Embedding(vocab_size,embedding_size)
        self.Attention = Attention(hidden_units)
        self.GRU = tf.keras.layers.GRU(
            hidden_units,
            return_sequences=True,
            return_state=True,
            recurrent_initializer='glorot_uniform'
        )
        self.Fc = tf.keras.layers.Dense(vocab_size)
            
    def call(self, x, encode_outs, pre_state):
        x = tf.expand_dims(x, axis=1)
        x = self.Embedding(x)
        context_vector, attention_weight = self.Attention(encode_outs, pre_state)
        context_vector = tf.expand_dims(context_vector, axis=1)
        gru_inp = tf.concat([x, context_vector], axis=-1)
        out_gru, state = self.GRU(gru_inp)
        out_gru = tf.reshape(out_gru, (-1, out_gru.shape[2]))
        return self.Fc(out_gru), state

# %% [markdown]
# # Loss function

# %%
def loss_function(real, pred):
    mask = 1-np.equal(real, 0)
    loss_ = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=real, logits=pred)*mask
    return tf.reduce_mean(loss_)

# %% [markdown]
# # Tiến hành train model

# %%
EPOCHS = 20
optimizer = tf.train.AdamOptimizer()
encoder = Encode(embedding_size, vocab_size=inp_lang.vocab_size, hidden_units=hidden_unit)
decoder = Decode(vocab_size=tar_lang.vocab_size, embedding_size=embedding_size, hidden_units=hidden_unit)
    
for epoch in range(EPOCHS):
    total_loss = 0
    for batch_id, (x, y) in enumerate(dataset.take(N_BATCH)):
        loss = 0
        with tf.GradientTape() as tape:
            first_state = encoder.init_hidden_state(batch_size=BATCH_SIZE)
            encode_outs, last_state = encoder(x, first_state)
            decode_state = last_state
            decode_input = [tar_lang.word2id["<start>"]]*BATCH_SIZE
            
            for i in range(1, y.shape[1]):
                decode_out, decode_state = decoder(
                        decode_input, encode_outs, decode_state
                )
                loss += loss_function(y[:, i], decode_out)
                decode_input = y[:, i]
                
            train_vars = encoder.trainable_variables
                        + decoder.trainable_variables
            grads = tape.gradient(loss, train_vars)
            optimizer.apply_gradients(zip(grads, train_vars))
        total_loss += loss
    print(total_loss.numpy())
# Out:
#   File "<ipython-input-20-6a954caf0812>", line 24
#     + decoder.trainable_variables
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# # Test model

# %%
def translate(inputs):
    result = ''
    hidden = encoder.init_hidden_state(batch_size=1)
    enc_out, enc_hidden = encoder(inputs, hidden)
    dec_hidden = enc_hidden  
    dec_input = [tar_lang.word2id['<start>']]
    
    for t in range(tar_lang.max_len):
        predictions, dec_hidden = decoder(dec_input, enc_out, dec_hidden)
        predicted_id = tf.argmax(predictions[0]).numpy()
        result += tar_lang.id2word[predicted_id] + ' '
        dec_input = [predicted_id]
    return result
  
for inp, tar in dataset.take(N_BATCH):
    print(translate(inp[1:2,:]))
    break
# Out:
# W0810 14:57:33.858738  2200 module_wrapper.py:136] From C:\Users\nguyen.pv162992\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow_core\python\util\module_wrapper.py:163: The name tf.estimator.inputs is deprecated. Please use tf.compat.v1.estimator.inputs instead.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-21e7f33bf373> in <module>
#      13     return result
#      14
# ---> 15 for inp, tar in dataset.take(N_BATCH):
#      16     print(translate(inp[1:2,:]))
#      17     break
#
# NameError: name 'dataset' is not defined
